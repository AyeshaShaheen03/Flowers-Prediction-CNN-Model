# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
TRAIN_DIR = "D:/AI projects/Neural-Network/lec4_cnn/seg_train"
TEST_DIR = "D:/AI projects/Neural-Network/lec4_cnn/seg_test"

# for cnn, it use for train
# Training generator
train_gen = ImageDataGenerator(rescale=1./255).flow_from_directory(
    TRAIN_DIR,
    target_size=(200, 200),
    batch_size=32,
    class_mode='categorical'
)

# Testing generator
test_gen = ImageDataGenerator(rescale=1./255).flow_from_directory(
    TEST_DIR,
    target_size=(200, 200),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 600 images belonging to 1 classes.
# Found 600 images belonging to 1 classes.

# %%
# for extra information, not required for model training
num_classes = len(train_gen.class_indices)
class_names = list(train_gen.class_indices.keys())
print("Class names:" , class_names)
print("Number of classes:" , num_classes )
print("Classes_directory:" , train_gen.class_indices)
# Out:
# Class names: ['seg_train']
# Number of classes: 1
# Classes_directory: {'seg_train': 0}

# %%
model = Sequential([
    # 32 means, 32 diff kernals houn gy with 3 by 3 metrix
    # relu is for which info or which info will precessand will pass to next, neg value to 0 mai convert
    # input shape means img size 200, 200, 3, 3 means gb  colors
    Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 3)),
      MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2), Flatten(),
    Dense(128, activation='relu'),
    # num_classes means output neurons, you can also write 6 here
    Dense(num_classes, activation='softmax')
])
# Out:
# d:\AI projects\Neural-Network\lec4_cnn\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 198, 198, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 99, 99, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 97, 97, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 46, 46, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 23, 23, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 67712)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     8,667,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,760,641 (33.42 MB)
#  Trainable params: 8,760,641 (33.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# train model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
#history is vaiable here
history = model.fit(train_gen, epochs=30, validation_data=test_gen, batch_size = 32)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 1.0000 - loss: 2.9045e-04 - val_accuracy: 0.5917 - val_loss: 3.9545
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 1.0000 - loss: 2.7207e-04 - val_accuracy: 0.5917 - val_loss: 3.9699
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 1.0000 - loss: 2.4757e-04 - val_accuracy: 0.5883 - val_loss: 4.0095
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 1.0000 - loss: 2.4194e-04 - val_accuracy: 0.5900 - val_loss: 4.0333
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 1.0000 - loss: 2.0709e-04 - val_accuracy: 0.5950 - val_loss: 4.0519
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 1.0000 - loss: 1.9849e-04 - val_accuracy: 0.5950 - val_loss: 4.0844
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 1.0000 - loss: 1.7977e-04 - val_accuracy: 0.5933 - val_loss: 4.1133
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 1.0000 - loss: 1.7300e-04 - val_accuracy: 0.5917 - val_loss: 4.1342
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 1.0000 - loss: 1.5841e-04 - val_accuracy: 0.5933 - val_loss: 4.1435
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 1.0000 - loss: 1.4550e-04 - val_accuracy: 0.5933 - val_loss: 4.1610
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 1.0000 - loss: 1.3868e-04 - val_accuracy: 0.5950 - val_loss: 4.1906
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 1.0000 - loss: 1.2528e-04 - val_accuracy: 0.5933 - val_loss: 4.2099
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 1.1707e-04 - val_accuracy: 0.5950 - val_loss: 4.2297
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 1.0000 - loss: 1.0807e-04 - val_accuracy: 0.5933 - val_loss: 4.2309
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 1.0000 - loss: 1.0246e-04 - val_accuracy: 0.5933 - val_loss: 4.2552
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 1.0000 - loss: 9.5700e-05 - val_accuracy: 0.5950 - val_loss: 4.2789
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 8.9193e-05 - val_accuracy: 0.5933 - val_loss: 4.2849
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 1.0000 - loss: 8.4400e-05 - val_accuracy: 0.5917 - val_loss: 4.3021
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 1.0000 - loss: 7.7702e-05 - val_accuracy: 0.5917 - val_loss: 4.3248
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 1.0000 - loss: 7.3043e-05 - val_accuracy: 0.5900 - val_loss: 4.3289
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 1.0000 - loss: 6.8542e-05 - val_accuracy: 0.5917 - val_loss: 4.3363
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 1.0000 - loss: 6.6026e-05 - val_accuracy: 0.5900 - val_loss: 4.3608
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 1.0000 - loss: 6.2196e-05 - val_accuracy: 0.5917 - val_loss: 4.3634
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 1.0000 - loss: 5.7422e-05 - val_accuracy: 0.5900 - val_loss: 4.3831
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 1.0000 - loss: 5.4343e-05 - val_accuracy: 0.5900 - val_loss: 4.4041
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 1.0000 - loss: 5.0412e-05 - val_accuracy: 0.5900 - val_loss: 4.4098
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 1.0000 - loss: 4.7732e-05 - val_accuracy: 0.5917 - val_loss: 4.4198
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 1.0000 - loss: 4.5070e-05 - val_accuracy: 0.5917 - val_loss: 4.4339
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 1.0000 - loss: 4.2568e-05 - val_accuracy: 0.5917 - val_loss: 4.4460

# %%
loss, acc = model.evaluate(test_gen)
print("Test Loss:" , loss)
print("Test Accuracy:" , acc)
# Out:
# d:\AI projects\Neural-Network\lec4_cnn\.venv\Lib\site-packages\keras\src\ops\nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# d:\AI projects\Neural-Network\lec4_cnn\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 18s 880ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Test Loss: 0.0
# Test Accuracy: 1.0

# %%
model.save("model.keras")
